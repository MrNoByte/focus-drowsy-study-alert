# %%
from google.colab import drive

drive.mount('/content/gdrive/')
# drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive/working projects/focus-drowsy
# %pwd
# Out:
# /content/gdrive/MyDrive/working projects/focus-drowsy
# '/content/gdrive/MyDrive/working projects/focus-drowsy'

# %%
# !pip install google_images_download

# %%
# from google.colab.patches import cv2_imshow
import cv2

# %%
# !pip install roboflow

# %%
# dataset already download at path
# /content/gdrive/MyDrive/working projects/focus-drowsy/Drowsiness-Detection-5-1


# from roboflow import Roboflow
# rf = Roboflow(api_key="4lm9RBQELgjExMLB2oq8")
# project = rf.workspace("assignmentpython").project("drowsiness-detection-5")
# dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.134`, to intall it `pip install ultralytics==8.0.134`.
# ...
# Extracting Dataset Version Zip to Drowsiness-Detection-5-1 in yolov8:: 100%|██████████| 604/604 [00:04<00:00, 131.23it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.4/609.4 kB 7.6 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train data="/content/gdrive/MyDrive/working projects/focus-drowsy/Drowsiness-Detection-5-1/data.yaml" model="/content/gdrive/MyDrive/working projects/focus-drowsy/yolov8n.pt" epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.0.159 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
